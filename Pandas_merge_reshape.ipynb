# %% [markdown]
# # Optional Activity
# More playing with toy dfs

# %% [markdown]
# 1) Make a dataframe with columns for name and birthday, containing this information for at least three people.
# 2) Make another dataframe with with columns for name and favorite falvor of cake, containing this information for at least three people.
# 3) Merge your two dfs useing any method (outer, innner, right, left)(ideally there will be at least one name that is in both dfs)
# 4) Extract the favorite flavor of cake for one person based on their name

# %% [markdown]
# # More Pandas (Yey)

# %%
df = pd.DataFrame({'ID': ['Alfa', 'Bravo', 'Charlie', 'Delta'],
                  'code10': [23,42,22,54],
                  'code11': [32,55,87,90]})

# %%
df
# Out:
#         ID  code10  code11
# 0     Alfa      23      32
# 1    Bravo      42      55
# 2  Charlie      22      87
# 3    Delta      54      90

# %% [markdown]
# ## Wide to Long

# %%
pd.wide_to_long(df, stubnames='code', i='ID', j='num').reset_index()
# Out:
#         ID  num  code
# 0     Alfa   10    23
# 1    Bravo   10    42
# 2  Charlie   10    22
# 3    Delta   10    54
# 4     Alfa   11    32
# 5    Bravo   11    55
# 6  Charlie   11    87
# 7    Delta   11    90

# %%
df = pd.DataFrame({'ID': ['Alfa', 'Bravo', 'Charlie', 'Delta'],
                  'code_10': [23,42,22,54],
                  'code_11': [32,55,87,90]})

# %%
pd.wide_to_long(df, stubnames='code', i='ID', j='num').reset_index()
# Out:
# Empty DataFrame
# Columns: [ID, num, code_10, code_11, code]
# Index: []

# %%
long_df = pd.wide_to_long(df, stubnames='code', i='ID', j='num', sep='_').reset_index()
long_df
# Out:
#         ID  num  code
# 0     Alfa   10    23
# 1    Bravo   10    42
# 2  Charlie   10    22
# 3    Delta   10    54
# 4     Alfa   11    32
# 5    Bravo   11    55
# 6  Charlie   11    87
# 7    Delta   11    90

# %% [markdown]
# ## Long to Wide

# %%
wide_df = long_df.pivot(index = 'ID', values = 'code', columns = 'num').reset_index()
wide_df
# Out:
# num       ID  10  11
# 0       Alfa  23  32
# 1      Bravo  42  55
# 2    Charlie  22  87
# 3      Delta  54  90

# %%
wide_df.rename(columns = {10: 'code_10', 11:'code_11'}, inplace = True)
wide_df
# Out:
# num       ID  code_10  code_11
# 0       Alfa       23       32
# 1      Bravo       42       55
# 2    Charlie       22       87
# 3      Delta       54       90

# %% [markdown]
# ## Let's look at some real data

# %% [markdown]
# Data from https://data.cityofchicago.org

# %%
import os
import pandas as pd

# %%
os.getcwd()
os.chdir('/Users/Sarah/Documents/GitHub/Programming_Lab_5-12-20')

# %%
os.listdir()
# Out:
# ['.DS_Store',
#  '.ipynb_checkpoints',
#  'Pandas_merge_reshape.ipynb',
#  '.git',
#  'Data']

# %%
os.chdir('/Users/Sarah/Documents/GitHub/Programming_Lab_5-12-20/Data')

# %%
os.listdir()
# Out:
# ['.DS_Store', 'Chicago_Death.csv', 'Chicago_SES.csv']

# %%
path = '/Users/Sarah/Documents/GitHub/Programming_Lab_5-12-20/Data'


mort_df = pd.read_csv(os.path.join(path, 'Chicago_Death.csv'))
SES_df = pd.read_csv(os.path.join(path, 'Chicago_SES.csv'))

# %%
mort_df.head()
# Out:
#   Cause of Death  Community Area Community Area Name  \
# 0     All Causes               1         Rogers Park
# 1     All Causes               2          West Ridge
# 2     All Causes               3              Uptown
# 3     All Causes               4      Lincoln Square
# 4     All Causes               5        North Center
#
#    Cumulative Deaths 2006 - 2010  Cumulative Deaths Rank  \
# 0                           1741                    22.0
# 1                           2612                     5.0
# 2                           2542                     6.0
# 3                           1108                    40.0
# 4                            690                    59.0
#
#    Average Annual Deaths 2006 - 2010  Average Crude Rate 2006 - 2010  \
# 0                                348                           614.2
# 1                                522                           723.6
# 2                                508                           879.6
# 3                                222                           547.0
# 4                                138                           433.0
#
#    Average Crude Rate Lower CI  Average Crude Rate Upper CI  Crude Rate Rank  \
# 0                        585.3                        643.1             51.0
# 1                        695.8                        751.4             42.0
# 2                        845.4                        913.8             31.0
# 3                        514.8                        579.2             60.0
# 4                        400.7                        465.3             68.0
#
#    Average Adjusted Rate 2006 - 2010  Average Adjusted Rate Lower CI  \
# 0                              895.2                           852.2
# 1                              689.9                           663.3
# 2                              934.0                           897.5
# 3                              698.7                           657.4
# 4                              681.2                           630.1
#
#    Average Adjusted Rate Upper CI  Adjusted Rate Rank  \
# 0                           939.3                29.0
# 1                           717.1                58.0
# 2                           971.2                24.0
# 3                           741.3                53.0
# 4                           734.3                61.0
#
#    Average Annual Years of Potential Life Lost (YPLL) Rate 2006 - 2010  \
# 0                                               7128
# 1                                               6123
# 2                                               9147
# 3                                               5344
# 4                                               4058
#
#    YPLL Rate RANK WARNING
# 0            37.0     NaN
# 1            49.0     NaN
# 2            31.0     NaN
# 3            62.0     NaN
# 4            74.0     NaN

# %%
mort_df.shape
# Out:
# (1404, 17)

# %%
comm_areas = mort_df['Community Area Name'].unique()
len(comm_areas)
# Out:
# 78

# %%
mort_df['Cause of Death'].unique()
# Out:
# array(['All Causes', 'All causes in males', 'All causes in females',
#        'Alzheimers disease', 'Cancer (all sites)', 'Assault (homicide)',
#        'Breast cancer in females', 'Colorectal cancer',
#        'Coronary heart disease', 'Diabetes-related', 'Firearm-related',
#        'Injury, unintentional',
#        'Kidney disease (nephritis, nephrotic syndrome and nephrosis)',
#        'Liver disease and cirrhosis', 'Lung cancer',
#        'Prostate cancer in males', 'Stroke (cerebrovascular disease)',
#        'Suicide (intentional self-harm)'], dtype=object)

# %% [markdown]
# ## Reshape

# %%
avg_an_death = mort_df.pivot(index = 'Community Area', columns='Cause of Death', 
                            values='Average Annual Deaths 2006 - 2010')

# %%
avg_an_death.head()
# Out:
# Cause of Death  All Causes  All causes in females  All causes in males  \
# Community Area
# 0                    19570                   9622                 9946
# 1                      348                    163                  185
# 2                      522                    262                  260
# 3                      508                    243                  266
# 4                      222                    101                  121
#
# Cause of Death  Alzheimers disease  Assault (homicide)  \
# Community Area
# 0                              348                 449
# 1                                5                   4
# 2                               11                   4
# 3                               11                   3
# 4                                3                   1
#
# Cause of Death  Breast cancer in females  Cancer (all sites)  \
# Community Area
# 0                                    360                4552
# 1                                      6                  72
# 2                                      9                 113
# 3                                      7                  95
# 4                                      4                  48
#
# Cause of Death  Colorectal cancer  Coronary heart disease  Diabetes-related  \
# Community Area
# 0                             499                    3418               625
# 1                              10                      75                12
# 2                              13                     104                18
# 3                              10                     116                20
# 4                               2                      43                 6
#
# Cause of Death  Firearm-related  Injury, unintentional  \
# Community Area
# 0                           415                    784
# 1                             3                     13
# 2                             3                     15
# 3                             3                     16
# 4                             1                      9
#
# Cause of Death  Kidney disease (nephritis, nephrotic syndrome and nephrosis)  \
# Community Area
# 0                                                             536
# 1                                                               8
# 2                                                              15
# 3                                                              14
# 4                                                               8
#
# Cause of Death  Liver disease and cirrhosis  Lung cancer  \
# Community Area
# 0                                       258         1180
# 1                                         5           17
# 2                                         5           27
# 3                                         8           25
# 4                                         4           13
#
# Cause of Death  Prostate cancer in males  Stroke (cerebrovascular disease)  \
# Community Area
# 0                                    282                               988
# 1                                      3                                12
# 2                                      5                                26
# 3                                      5                                21
# 4                                      3                                10
#
# Cause of Death  Suicide (intentional self-harm)
# Community Area
# 0                                           177
# 1                                             4
# 2                                             4
# 3                                             5
# 4                                             3

# %%
avg_an_death.shape
# Out:
# (78, 18)

# %%
comm_areas = mort_df['Community Area Name'].unique()
len(comm_areas)
# Out:
# 78

# %% [markdown]
# ### Check for Nan

# %%
SES_df.head()
# Out:
#    Community Area Number COMMUNITY AREA NAME  PERCENT OF HOUSING CROWDED  \
# 0                    1.0         Rogers Park                         7.7
# 1                    2.0          West Ridge                         7.8
# 2                    3.0              Uptown                         3.8
# 3                    4.0      Lincoln Square                         3.4
# 4                    5.0        North Center                         0.3
#
#    PERCENT HOUSEHOLDS BELOW POVERTY  PERCENT AGED 16+ UNEMPLOYED  \
# 0                              23.6                          8.7
# 1                              17.2                          8.8
# 2                              24.0                          8.9
# 3                              10.9                          8.2
# 4                               7.5                          5.2
#
#    PERCENT AGED 25+ WITHOUT HIGH SCHOOL DIPLOMA  \
# 0                                          18.2
# 1                                          20.8
# 2                                          11.8
# 3                                          13.4
# 4                                           4.5
#
#    PERCENT AGED UNDER 18 OR OVER 64  PER CAPITA INCOME   HARDSHIP INDEX
# 0                              27.5               23939            39.0
# 1                              38.5               23040            46.0
# 2                              22.2               35787            20.0
# 3                              25.5               37524            17.0
# 4                              26.2               57123             6.0

# %%
SES_df.shape
# Out:
# (78, 9)

# %%
SES_df.isna().any()
# Out:
# Community Area Number                            True
# COMMUNITY AREA NAME                             False
# PERCENT OF HOUSING CROWDED                      False
# PERCENT HOUSEHOLDS BELOW POVERTY                False
# PERCENT AGED 16+ UNEMPLOYED                     False
# PERCENT AGED 25+ WITHOUT HIGH SCHOOL DIPLOMA    False
# PERCENT AGED UNDER 18 OR OVER 64                False
# PER CAPITA INCOME                               False
# HARDSHIP INDEX                                   True
# dtype: bool

# %%
SES_df.isna().any().any()
#true if any in the any are T
# Out:
# True

# %%
SES_df.isna().any().all()
#now only T if they were all T, so all in this serise of df.isany().any() is full of True
# Out:
# False

# %% [markdown]
# ### Another way to look at NAs
# #### From Alberto Nieto
# https://www.youtube.com/watch?v=RNwIE7zp8qE&feature=youtu.be

# %%
# Set the field to check nulls for
field_to_check = "Community Area Number"

# Determine how many rows are in the table
rowcount = SES_df.shape[0]

# Determine how many rows have null Longitude
null_long_rowcount = SES_df.loc[SES_df[field_to_check].isnull()].shape[0]

# Calculate how much of the data this represents as a percentage
percentage_null_long = round((null_long_rowcount / rowcount) * 100, 2)

# Use a print statement to report this information
print("There were "+str(null_long_rowcount)+" records with null "+str(field_to_check)+" values in the data.\nThis amounts to " +str(percentage_null_long)+"% of the available data.")
# Out:
# There were 1 records with null Community Area Number values in the data.
# This amounts to 1.28% of the available data.

# %%
SES_df[SES_df['Community Area Number'].isna()]
# Out:
#     Community Area Number COMMUNITY AREA NAME  PERCENT OF HOUSING CROWDED  \
# 77                    NaN             CHICAGO                         4.7
#
#     PERCENT HOUSEHOLDS BELOW POVERTY  PERCENT AGED 16+ UNEMPLOYED  \
# 77                              19.7                         12.9
#
#     PERCENT AGED 25+ WITHOUT HIGH SCHOOL DIPLOMA  \
# 77                                          19.5
#
#     PERCENT AGED UNDER 18 OR OVER 64  PER CAPITA INCOME   HARDSHIP INDEX
# 77                              33.5               28202             NaN

# %% [markdown]
# ## Merge

# %%
avg_an_death.columns
# Out:
# Index(['All Causes', 'All causes in females', 'All causes in males',
#        'Alzheimers disease', 'Assault (homicide)', 'Breast cancer in females',
#        'Cancer (all sites)', 'Colorectal cancer', 'Coronary heart disease',
#        'Diabetes-related', 'Firearm-related', 'Injury, unintentional',
#        'Kidney disease (nephritis, nephrotic syndrome and nephrosis)',
#        'Liver disease and cirrhosis', 'Lung cancer',
#        'Prostate cancer in males', 'Stroke (cerebrovascular disease)',
#        'Suicide (intentional self-harm)'],
#       dtype='object', name='Cause of Death')

# %%
avg_an_death['Community Area'].head()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2896             try:
# -> 2897                 return self._engine.get_loc(key)
#    2898             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Community Area'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-155-4b103d601448> in <module>
# ----> 1 avg_an_death['Community Area'].head()
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2993             if self.columns.nlevels > 1:
#    2994                 return self._getitem_multilevel(key)
# -> 2995             indexer = self.columns.get_loc(key)
#    2996             if is_integer(indexer):
#    2997                 indexer = [indexer]
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2897                 return self._engine.get_loc(key)
#    2898             except KeyError:
# -> 2899                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2900         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#    2901         if indexer.ndim > 1 or indexer.size > 1:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Community Area'

# %%
avg_an_death.reset_index(inplace = True)
avg_an_death.head()
# Out:
# Cause of Death  Community Area  All Causes  All causes in females  \
# 0                            0       19570                   9622
# 1                            1         348                    163
# 2                            2         522                    262
# 3                            3         508                    243
# 4                            4         222                    101
#
# Cause of Death  All causes in males  Alzheimers disease  Assault (homicide)  \
# 0                              9946                 348                 449
# 1                               185                   5                   4
# 2                               260                  11                   4
# 3                               266                  11                   3
# 4                               121                   3                   1
#
# Cause of Death  Breast cancer in females  Cancer (all sites)  \
# 0                                    360                4552
# 1                                      6                  72
# 2                                      9                 113
# 3                                      7                  95
# 4                                      4                  48
#
# Cause of Death  Colorectal cancer  Coronary heart disease  Diabetes-related  \
# 0                             499                    3418               625
# 1                              10                      75                12
# 2                              13                     104                18
# 3                              10                     116                20
# 4                               2                      43                 6
#
# Cause of Death  Firearm-related  Injury, unintentional  \
# 0                           415                    784
# 1                             3                     13
# 2                             3                     15
# 3                             3                     16
# 4                             1                      9
#
# Cause of Death  Kidney disease (nephritis, nephrotic syndrome and nephrosis)  \
# 0                                                             536
# 1                                                               8
# 2                                                              15
# 3                                                              14
# 4                                                               8
#
# Cause of Death  Liver disease and cirrhosis  Lung cancer  \
# 0                                       258         1180
# 1                                         5           17
# 2                                         5           27
# 3                                         8           25
# 4                                         4           13
#
# Cause of Death  Prostate cancer in males  Stroke (cerebrovascular disease)  \
# 0                                    282                               988
# 1                                      3                                12
# 2                                      5                                26
# 3                                      5                                21
# 4                                      3                                10
#
# Cause of Death  Suicide (intentional self-harm)
# 0                                           177
# 1                                             4
# 2                                             4
# 3                                             5
# 4                                             3

# %%
avg_an_death['Community Area'].head()
# Out:
# 0    0
# 1    1
# 2    2
# 3    3
# 4    4
# Name: Community Area, dtype: int64

# %%
SES_df.columns
# Out:
# Index(['Community Area Number', 'COMMUNITY AREA NAME',
#        'PERCENT OF HOUSING CROWDED', 'PERCENT HOUSEHOLDS BELOW POVERTY',
#        'PERCENT AGED 16+ UNEMPLOYED',
#        'PERCENT AGED 25+ WITHOUT HIGH SCHOOL DIPLOMA',
#        'PERCENT AGED UNDER 18 OR OVER 64', 'PER CAPITA INCOME ',
#        'HARDSHIP INDEX'],
#       dtype='object')

# %%
merge1 = avg_an_death.merge(SES_df, left_on = 'Community Area', right_on ='Community Area Number', how = 'inner')
merge1.head()
# Out:
#    Community Area  All Causes  All causes in females  All causes in males  \
# 0               1         348                    163                  185
# 1               2         522                    262                  260
# 2               3         508                    243                  266
# 3               4         222                    101                  121
# 4               5         138                     74                   64
#
#    Alzheimers disease  Assault (homicide)  Breast cancer in females  \
# 0                   5                   4                         6
# 1                  11                   4                         9
# 2                  11                   3                         7
# 3                   3                   1                         4
# 4                   2                   0                         2
#
#    Cancer (all sites)  Colorectal cancer  Coronary heart disease  ...  \
# 0                  72                 10                      75  ...
# 1                 113                 13                     104  ...
# 2                  95                 10                     116  ...
# 3                  48                  2                      43  ...
# 4                  31                  5                      27  ...
#
#    Suicide (intentional self-harm)  Community Area Number  \
# 0                                4                    1.0
# 1                                4                    2.0
# 2                                5                    3.0
# 3                                3                    4.0
# 4                                3                    5.0
#
#    COMMUNITY AREA NAME  PERCENT OF HOUSING CROWDED  \
# 0          Rogers Park                         7.7
# 1           West Ridge                         7.8
# 2               Uptown                         3.8
# 3       Lincoln Square                         3.4
# 4         North Center                         0.3
#
#    PERCENT HOUSEHOLDS BELOW POVERTY  PERCENT AGED 16+ UNEMPLOYED  \
# 0                              23.6                          8.7
# 1                              17.2                          8.8
# 2                              24.0                          8.9
# 3                              10.9                          8.2
# 4                               7.5                          5.2
#
#    PERCENT AGED 25+ WITHOUT HIGH SCHOOL DIPLOMA  \
# 0                                          18.2
# 1                                          20.8
# 2                                          11.8
# 3                                          13.4
# 4                                           4.5
#
#    PERCENT AGED UNDER 18 OR OVER 64  PER CAPITA INCOME   HARDSHIP INDEX
# 0                              27.5               23939            39.0
# 1                              38.5               23040            46.0
# 2                              22.2               35787            20.0
# 3                              25.5               37524            17.0
# 4                              26.2               57123             6.0
#
# [5 rows x 28 columns]

# %%
merge1.shape
# Out:
# (77, 28)

# %%
merge2 = avg_an_death.merge(SES_df, left_on = 'Community Area', right_on ='Community Area Number', how = 'left')
merge2.shape
# Out:
# (78, 28)

# %%
merge3 = avg_an_death.merge(SES_df, left_on = 'Community Area', right_on ='Community Area Number', how = 'right')
merge3.shape
# Out:
# (78, 28)

# %%
merge3[merge3['Community Area Number'].isna()]
# Out:
#     Community Area  All Causes  All causes in females  All causes in males  \
# 77             NaN         NaN                    NaN                  NaN
#
#     Alzheimers disease  Assault (homicide)  Breast cancer in females  \
# 77                 NaN                 NaN                       NaN
#
#     Cancer (all sites)  Colorectal cancer  Coronary heart disease  ...  \
# 77                 NaN                NaN                     NaN  ...
#
#     Suicide (intentional self-harm)  Community Area Number  \
# 77                              NaN                    NaN
#
#     COMMUNITY AREA NAME  PERCENT OF HOUSING CROWDED  \
# 77              CHICAGO                         4.7
#
#     PERCENT HOUSEHOLDS BELOW POVERTY  PERCENT AGED 16+ UNEMPLOYED  \
# 77                              19.7                         12.9
#
#     PERCENT AGED 25+ WITHOUT HIGH SCHOOL DIPLOMA  \
# 77                                          19.5
#
#     PERCENT AGED UNDER 18 OR OVER 64  PER CAPITA INCOME   HARDSHIP INDEX
# 77                              33.5               28202             NaN
#
# [1 rows x 28 columns]

# %%
merge2[merge2['Community Area Number'].isna()]
# Out:
#    Community Area  All Causes  All causes in females  All causes in males  \
# 0               0       19570                   9622                 9946
#
#    Alzheimers disease  Assault (homicide)  Breast cancer in females  \
# 0                 348                 449                       360
#
#    Cancer (all sites)  Colorectal cancer  Coronary heart disease  ...  \
# 0                4552                499                    3418  ...
#
#    Suicide (intentional self-harm)  Community Area Number  \
# 0                              177                    NaN
#
#    COMMUNITY AREA NAME  PERCENT OF HOUSING CROWDED  \
# 0                  NaN                         NaN
#
#    PERCENT HOUSEHOLDS BELOW POVERTY  PERCENT AGED 16+ UNEMPLOYED  \
# 0                               NaN                          NaN
#
#    PERCENT AGED 25+ WITHOUT HIGH SCHOOL DIPLOMA  \
# 0                                           NaN
#
#    PERCENT AGED UNDER 18 OR OVER 64  PER CAPITA INCOME   HARDSHIP INDEX
# 0                               NaN                 NaN             NaN
#
# [1 rows x 28 columns]
